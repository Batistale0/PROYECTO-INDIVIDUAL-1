# %%
#Importamos las librerias a usar
import pandas as pd
import numpy as np
import ast
import re
import json

# %%
#Leemos el archivo csv
df_credits = pd.read_csv('Archivos csv\credits.csv')
df_credits
# Out:
#                                                     cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 45471  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 45472  [{'cast_id': 1002, 'character': 'Sister Angela...
# 45473  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45474  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45475                                                 []
#
#                                                     crew      id
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...     862
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...    8844
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...   15602
# ...

# %%
df_credits.isnull().sum()
# Out:
# cast    0
# crew    0
# id      0
# dtype: int64

# %%
# Convertir la columna 'cast' en un DataFrame utilizando json_normalize()
df_cast = pd.json_normalize(df_credits['cast'])

# %%
df_credits = pd.concat([df_credits, df_cast], axis=1)

# %%
df_credits
# Out:
#                                                     cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 45471  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 45472  [{'cast_id': 1002, 'character': 'Sister Angela...
# 45473  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45474  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45475                                                 []
#
#                                                     crew      id
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...     862
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...    8844
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...   15602
# ...

# %%
#Convertimos en lista la columna cast
df_credits ['cast'] = df_credits['cast'].apply(ast.literal_eval)

#Aqui extraemos los nombres
def extract_cast_name(cast_list):
    cast_name = [castt['name'] for castt in cast_list]
    return', '.join(cast_name)
#aplicamos la funcion que hicimos
df_credits['castt'] = df_credits['cast'].apply(extract_cast_name)

df_credits.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': 'Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862
#
#                                                castt
# 0  Tom Hanks, Tim Allen, Don Rickles, Jim Varney,...
# 1  Robin Williams, Jonathan Hyde, Kirsten Dunst, ...
# 2  Walter Matthau, Jack Lemmon, Ann-Margret, Soph...
# 3  Whitney Houston, Angela Bassett, Loretta Devin...
# ...

# %%
#Convertimos en lista la columna crew
df_credits ['crew'] = df_credits['crew'].apply(ast.literal_eval)

#Extraemos los nombres
def extract_crew_name(crew_list):
    crew_name = [creww['name'] for creww in crew_list]
    return', '.join(crew_name)
#aplicamos la funcion
df_credits['creww'] = df_credits['crew'].apply(extract_cast_name)

df_credits.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': 'Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862
#
#                                                castt  \
# 0  Tom Hanks, Tim Allen, Don Rickles, Jim Varney,...
# 1  Robin Williams, Jonathan Hyde, Kirsten Dunst, ...
# 2  Walter Matthau, Jack Lemmon, Ann-Margret, Soph...
# 3  Whitney Houston, Angela Bassett, Loretta Devin...
# ...

# %%
df_credits.drop(['cast', 'crew'], axis=1, inplace=True)

# %%
df_credits.head()
# Out:
#       id                                              castt  \
# 0    862  Tom Hanks, Tim Allen, Don Rickles, Jim Varney,...
# 1   8844  Robin Williams, Jonathan Hyde, Kirsten Dunst, ...
# 2  15602  Walter Matthau, Jack Lemmon, Ann-Margret, Soph...
# 3  31357  Whitney Houston, Angela Bassett, Loretta Devin...
# 4  11862  Steve Martin, Diane Keaton, Martin Short, Kimb...
#
#                                                creww
# 0  John Lasseter, Joss Whedon, Andrew Stanton, Jo...
# 1  Larry J. Franco, Jonathan Hensleigh, James Hor...
# 2  Howard Deutch, Mark Steven Johnson, Mark Steve...
# 3  Forest Whitaker, Ronald Bass, Ronald Bass, Ezr...
# 4  Alan Silvestri, Elliot Davis, Nancy Meyers, Na...

# %%
df_credits.isnull().sum()
# Out:
# id       0
# castt    0
# creww    0
# dtype: int64

# %%
#Guardamos todo en un nuevo csv
df_credits.to_csv('credits_terminado.csv', index=False)
